# %% [markdown]
# <a href="https://colab.research.google.com/github/einetapir/NLP_offspring_singles/blob/main/NLP_offspring_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Projets_Perso/NLP_offspring/'
df = pd.read_csv(path + 'offspring_lyrics.csv')
df.head(30)
# Out:
#     date  ...                                             lyrics
# 0   1994  ...    [Intro] You gotta keep 'em separated  [Verse...
# 1   1994  ...    [Intro] La, la, la, la, la La, la, la, la, l...
# 2   1994  ...    [Verse 1] Getting edgy all the time Someone ...
# 3   1997  ...    [Chorus] We've been playing now for much too...
# 4   1997  ...    [Verse 1] Maybe in another life I could find...
# 5   1998  ...    [Intro: Sample] Gunter glieben glauten globe...
# 6   1999  ...    [Verse 1] My friend's got a girlfriend Man, ...
# 7   1998  ...    [Verse 1] When we were young the future was ...
# 8   1998  ...    [Verse 1] I'm seeing this girl and she just ...
# 9   2000  ...    [Intro] You can do it!  [Verse 1: Offspring]...
# 10  2000  ...    [Verse 1] If you could only read my mind You...
# 11  2000  ...    [Verse 1] There was a time, looking through ...
# 12  2005  ...    [Verse 1] You may push me around But you can...
# ...
